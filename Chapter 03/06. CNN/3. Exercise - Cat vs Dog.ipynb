# %% [markdown]
# <h2 align="center"> Cats vs Dogs </h2>
# <h2 align="center" style="color:#01ff84"> Loading your dataset</h2>
#
#
# <br>
#
# So far we've been working with fairly artificial datasets that you wouldn't typically be using in real projects. Instead, you'll likely be dealing with full-sized images like you'd get from smart phone cameras. In this notebook, we'll look at how to load images and use them to train neural networks.
#
# We'll be using a [dataset of cat and dog photos](https://www.kaggle.com/c/dogs-vs-cats) available from Kaggle. Here are a couple example images:
#
# <img src="imgs/dog.png" width="200" height="40" />
# <img src="imgs/cat.png" width="200" height="40" />
#
# We'll use this dataset to train a neural network that can differentiate between cats and dogs. These days it doesn't seem like a big accomplishment, but five years ago it was a serious challenge for computer vision systems.
#
# <br>
#
# Start importing the needed libraries:

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms
from sklearn.metrics import accuracy_score

# %% [markdown]
# The easiest way to load image data is with `datasets.ImageFolder` from `torchvision` ([documentation](http://pytorch.org/docs/master/torchvision/datasets.html#imagefolder)). In general you'll use `ImageFolder` like so:
#
# ```python
# dataset = datasets.ImageFolder('path/to/data', transform=transform)
# ```
#
# where `'path/to/data'` is the file path to the data directory and `transform` is a list of processing steps built with the [`transforms`](http://pytorch.org/docs/master/torchvision/transforms.html) module from `torchvision`. ImageFolder expects the files and directories to be constructed like so:
# ```
# root/dog/xxx.png
# root/dog/xxy.png
# root/dog/xxz.png
#
# root/cat/123.png
# root/cat/nsdf3.png
# root/cat/asd932_.png
# ```
#
# where each class has it's own directory (`cat` and `dog`) for the images. The images are then labeled with the class taken from the directory name. So here, the image `123.png` would be loaded with the class label `cat`. You can download the dataset already structured like this [from here](https://s3.amazonaws.com/content.udacity-data.com/nd089/Cat_Dog_data.zip). They are already splitted into a training set and test set.
#
#
# >**Exercise:** Download the dataset and place the train and test set in the `datasets/cat_vs_dog` folder. If you're cloning this from github, you should have it in `../datasets/`. So first create the `cat_vs_dog` folder in `datasets` and verify that the data are there by running `ls ../datasets/cat_vs_dog` (or your custom path if you changed it).

# %% [markdown]
# Great! Now that you have downloaded your data, you need to define the transformations to be passed to the `ImageFolder` function. You have already used them with the MNIST dataset (see the Data Augmentation workbook in Pytorch). While for MNIST you were passing the transformation in the following line of code
#
# `datasets.MNIST('~/.pytorch/MNIST_data/', download=True, train=True, transform=transform)`
#
# here you do it in the `ImageFolder` method. You can think it as a way to work on every dataset, not only on the MNIST one.
#
#
# ### Transforms
#
# When you load in the data with `ImageFolder`, you'll need to define some transforms. For example, the images are different sizes but we'll need them to all be the same size for training. You can either resize them with `transforms.Resize()` or crop with `transforms.CenterCrop()`, `transforms.RandomResizedCrop()`, etc. We'll also need to convert the images to PyTorch tensors with `transforms.ToTensor()`. Typically you'll combine these transforms into a pipeline with `transforms.Compose()`, which accepts a list of transforms and runs them in sequence.
#
# As in the other notebook, you can use the following transformations:
#
# ```python
# transform = transforms.Compose([transforms.RandomRotation(30),
#                                        transforms.RandomResizedCrop(224),
#                                        transforms.RandomHorizontalFlip(),
#                                        transforms.ToTensor(),
#                                        transforms.Normalize([0.5, 0.5, 0.5],
#                                                             [0.5, 0.5, 0.5])])
#
# ```
#
# **WARNING!** Remember that transformation are super useful for "augmenting" your training data, so that you make your network less vulnerable to different sizes, rotations, or cropping. However, when you are on the test data, there is no need of augmenting the data! Actually, it is not a good practice to do that because there would be very repetitive test data that invalidates your score.
#
# For this reason, define two different transformations for training and test data (remember that `ToTensor()` and normalization are necessary also for the test data, as well as the resizing (you can use `transforms.Resize(size)` for it):

# %%
train_transform = transforms.Compose([transforms.Resize(255),
                                       transforms.RandomRotation(30),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.5, 0.5, 0.5],
                                                            [0.5, 0.5, 0.5])])

test_transform = transforms.Compose([transforms.Resize(255),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.5, 0.5, 0.5],
                                                           [0.5, 0.5, 0.5])])


data_dir = "C:\\Users\\ritth\\code\\Strive\\Strive-Exercises\\Chapter 03\\06. CNN\\datasets\\cat_vs_dog" # or the path where you have downloaded the dataset

train_data = datasets.ImageFolder(data_dir + '/train', transform=train_transform)
test_data = datasets.ImageFolder(data_dir + '/test', transform=test_transform)

# %% [markdown]
# Now that you have you have defined the needed transformation, it's time to build the Data loader itself!
#
# ### Data Loaders
#
# With the `ImageFolder` loaded, you have to pass it to a [`DataLoader`](http://pytorch.org/docs/master/data.html#torch.utils.data.DataLoader). The `DataLoader` takes a dataset (such as you would get from `ImageFolder`) and returns batches of images and the corresponding labels. You can set various parameters like the batch size and if the data is shuffled after each epoch.
#
# ```python
# dataloader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)
# ```
#
# Here `dataloader` is a [generator](https://jeffknupp.com/blog/2013/04/07/improve-your-python-yield-and-generators-explained/). To get data out of it, you need to loop through it or convert it to an iterator and call `next()`.
#
# ```python
# # Looping through it, get a batch on each loop
# for images, labels in dataloader:
#     pass
#
# # Get one batch
# images, labels = next(iter(dataloader))
# ```
#
# >**Exercise:** Build the dataloader for both the train and test data. Choose the batch size that fits your memory.
# **Remember** NOT TO shuffle the test data!

# %%
from torch.utils.data import DataLoader
trainloader =  DataLoader(train_data, batch_size=32, shuffle=True)
testloader = DataLoader(test_data, batch_size=32, shuffle=False)
trainloader

# %%
len(trainloader.dataset)
# Out:
# 2

# %%
def imshow(image, ax=None, title=None, normalize=True):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax


# Run this to test your data loaders
images, labels = next(iter(trainloader))
imshow(images[0], normalize=False)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <AxesSubplot:>

# %% [markdown]
# Ok, now let's create a simple Convolutional Neural Network for this task!

# %% [markdown]
# **N.B.** When building a convolutional neural network, be careful for making all the shapes to match.

# %%
# import torch.nn as nn
# import torch.nn.functional as F
# import torch.optim as optim

# class Net(nn.Module):
#     def __init__(self):
#         super(Net, self).__init__()
#         self.conv1 = nn.Conv2d(3, 32, 5)     # 224 - 5 // 1 +1 --> 109    # in_channels means RGB = 3, Grey = 1
#         self.pool = nn.MaxPool2d(2, 2)       # 109 -2 // 2 + 1  --> 3
#         self.conv2 = nn.Conv2d(32, 16, 5)    # 35 - 5 // 1 +1 --> 15     
#         self.fc1 = nn.Linear(16*5*5, 120)
#         self.fc2 = nn.Linear(120, 84)
#         self.fc3 = nn.Linear(84, 2)

#     def forward(self, x):
#         x = self.pool(F.relu(self.conv1(x)))
#         x = self.pool(F.relu(self.conv2(x)))
#         print(x.shape)
# #         x = x.view(x.shape[0], -1)
# #         x = F.relu(self.fc1(x))
# #         x = F.relu(self.fc2(x))
# #         x = self.fc3(x)
# #         x = F.log_softmax(x, dim=1)
# #         return x


# net = Net()
# # optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
# # criterion = nn.NLLLoss()

# %% [markdown]
# Why do we reshape in the middle of the forward pass?
#
# As you remember from the class, the output of a convolutional layer is always a 3D volume! For this reason, since the output channels of the conv2 layer is 16 and the feature maps have size 5x5, then the input of the fc1 layer must be reshaped to have shape `(batch_size, 16 * 5 * 5)`.
#
# Now the question is: what will be the difference in the training of this network with respect to the fully-connected one you are used to?
#
# None, except for the fact that you do not reshape the input to be a vector, but you keep the shape as a volume!
#
# >**Exercise:** Implement a Convolutional Neural Network for the cat vs dog challenge, such that:
# > - The input images have shape 28x28 and three RGB channels
# > - You have 2 Conv2d layer with MaxPool2D in the middle and two fully-connected layer at the end.
# > - You can decide yourself the rest of the hyperparameters (kernel size, number of filters...)
# > - Train and evaluate your model
#
# Following there's an helper function to visualize your prediction once your model has been built.

# %%
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 64, 3, 2, 2)     
        self.pool = nn.MaxPool2d(2, 2)       
        self.conv2 = nn.Conv2d(64, 32, 3, 2)    
        self.fc1 = nn.Linear(32*13*13, 156)
        self.fc2 = nn.Linear(156, 84)
        self.fc3 = nn.Linear(84, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        #print(x.shape)
        x = x.view(x.shape[0], -1)   
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        x = F.log_softmax(x, dim=1)
        return x


net = Net()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)
criterion = nn.NLLLoss()
#net(images).shape

# %%
device= 'cuda' if torch.cuda.is_available() else "cpu"
net.to(device)
print(device)
# Out:
# cpu

# %%
import numpy as np
class_list = train_data.classes

def view_classify_general(img, ps, class_list):
    ''' Function for viewing an image and it's predicted classes.
    '''
    ps = ps.data.numpy().squeeze()

    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    imshow(img, ax=ax1, normalize=True)
    ax1.axis('off')
    ax2.barh(np.arange(len(class_list)), ps)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(len(class_list)))
    ax2.set_yticklabels([x for x in class_list], size='small')
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)

    plt.tight_layout()

images, labels = next(iter(trainloader))
img, label = images[0], labels[0]
# Flatten images
# Forward pass, get our logits
logits = net(img.view(1, *images[0].shape))
# Calculate the loss with the logits and the labels
ps = torch.exp(logits)
    
view_classify_general(img, ps, class_list)

# %% [markdown]
# You should get something cute like this:
#
# ![image](imgs/cat_pred.png)

# %%
num_epochs = 100  


train_losses = []
test_losses = []


for epoch in range(num_epochs):
    
    train_epoch_losses = 0

    # training
    for images, labels in trainloader:

        # device
        images=images.to(device)
        labels=labels.to(device)

        # forward pass
        optimizer.zero_grad()
        output = net.forward(images)
        
        # loss
        train_loss = criterion(output, labels)

        # backward pass
        train_loss.backward()
        optimizer.step()


        train_epoch_losses += train_loss.item()


    
    # validation
    net.eval()

    with torch.no_grad():
        test_accuracies = 0
        test_epoch_losses = 0

        for imagest, labelst in testloader:
            imagest = imagest.to(device)
            labelst = labelst.to(device)

            test_output = net.forward(imagest)
            test_loss = criterion(test_output, labelst)
            test_epoch_losses += test_loss.item()
            
            
            # accuracy
            ps = torch.exp(test_output)
            top_p, top_class = ps.topk(1, dim=1)                        # top_p = probability, top_class = index
            equals = (top_class == labels.view(* top_class.shape))
            test_accuracies += equals.sum().item()
            
        
        
    net.train()

    # Get mean loss to enable comparison between train and test sets
    train_loss = train_epoch_losses/ len(trainloader.dataset)
    test_loss = test_epoch_losses / len(testloader.dataset)
    
    # At completion of epoch
    train_losses.append(train_loss)
    test_losses.append(test_loss)


    print("Epoch: {}/{}.. ".format(epoch+1, num_epochs),
              "Training Loss {:.3f}.. ".format(train_loss),
              "Test Loss {:.3f}.. ".format(test_loss),
              "Test Accuracy {:.3f}".format(test_accuracies / len(testloader.dataset)))



# Plots
x_epochs = list(range(num_epochs))
plt.figure(figsize = (10, 8))
plt.plot(x_epochs, train_losses, marker='o', label='train')
plt.plot(x_epochs, test_losses, marker='o', label='test')
plt.plot(x_epochs, test_accuracies, marker='o', label='test')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()


plt.show()
# Out:
# Epoch: 1/100..  Training Loss 0.346..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 2/100..  Training Loss 0.348..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 3/100..  Training Loss 0.348..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 4/100..  Training Loss 0.347..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 5/100..  Training Loss 0.346..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 6/100..  Training Loss 0.347..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 7/100..  Training Loss 0.347..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 8/100..  Training Loss 0.346..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 9/100..  Training Loss 0.344..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 10/100..  Training Loss 0.346..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 11/100..  Training Loss 0.346..  Test Loss 0.348..  Test Accuracy 0.500
# Epoch: 12/100..  Training Loss 0.346..  Test Loss 0.348..  Test Accuracy 0.500
# Epoch: 13/100..  Training Loss 0.349..  Test Loss 0.348..  Test Accuracy 0.500
# Epoch: 14/100..  Training Loss 0.347..  Test Loss 0.348..  Test Accuracy 0.500
# Epoch: 15/100..  Training Loss 0.347..  Test Loss 0.348..  Test Accuracy 0.500
# Epoch: 16/100..  Training Loss 0.345..  Test Loss 0.348..  Test Accuracy 0.500
# Epoch: 17/100..  Training Loss 0.346..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 18/100..  Training Loss 0.343..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 19/100..  Training Loss 0.350..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 20/100..  Training Loss 0.346..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 21/100..  Training Loss 0.345..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 22/100..  Training Loss 0.345..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 23/100..  Training Loss 0.343..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 24/100..  Training Loss 0.348..  Test Loss 0.347..  Test Accuracy 0.500
# Epoch: 25/100..  Training Loss 0.344..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 26/100..  Training Loss 0.347..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 27/100..  Training Loss 0.344..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 28/100..  Training Loss 0.345..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 29/100..  Training Loss 0.345..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 30/100..  Training Loss 0.344..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 31/100..  Training Loss 0.346..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 32/100..  Training Loss 0.346..  Test Loss 0.346..  Test Accuracy 0.500
# Epoch: 33/100..  Training Loss 0.345..  Test Loss 0.345..  Test Accuracy 0.500
# Epoch: 34/100..  Training Loss 0.344..  Test Loss 0.345..  Test Accuracy 0.500
# Epoch: 35/100..  Training Loss 0.346..  Test Loss 0.345..  Test Accuracy 0.500
# Epoch: 36/100..  Training Loss 0.346..  Test Loss 0.345..  Test Accuracy 0.500
# Epoch: 37/100..  Training Loss 0.348..  Test Loss 0.345..  Test Accuracy 0.500
# Epoch: 38/100..  Training Loss 0.344..  Test Loss 0.344..  Test Accuracy 0.500
# Epoch: 39/100..  Training Loss 0.345..  Test Loss 0.344..  Test Accuracy 0.500
# Epoch: 40/100..  Training Loss 0.342..  Test Loss 0.344..  Test Accuracy 0.500
# Epoch: 41/100..  Training Loss 0.344..  Test Loss 0.344..  Test Accuracy 0.500
# Epoch: 42/100..  Training Loss 0.343..  Test Loss 0.344..  Test Accuracy 0.500
# Epoch: 43/100..  Training Loss 0.347..  Test Loss 0.344..  Test Accuracy 0.500
# Epoch: 44/100..  Training Loss 0.345..  Test Loss 0.343..  Test Accuracy 0.500
# Epoch: 45/100..  Training Loss 0.343..  Test Loss 0.343..  Test Accuracy 1.000
# Epoch: 46/100..  Training Loss 0.341..  Test Loss 0.343..  Test Accuracy 0.000
# Epoch: 47/100..  Training Loss 0.344..  Test Loss 0.343..  Test Accuracy 1.000
# Epoch: 48/100..  Training Loss 0.344..  Test Loss 0.343..  Test Accuracy 1.000
# Epoch: 49/100..  Training Loss 0.346..  Test Loss 0.343..  Test Accuracy 0.000
# Epoch: 50/100..  Training Loss 0.344..  Test Loss 0.343..  Test Accuracy 1.000
# Epoch: 51/100..  Training Loss 0.341..  Test Loss 0.342..  Test Accuracy 0.000
# Epoch: 52/100..  Training Loss 0.343..  Test Loss 0.342..  Test Accuracy 0.000
# Epoch: 53/100..  Training Loss 0.344..  Test Loss 0.342..  Test Accuracy 1.000
# Epoch: 54/100..  Training Loss 0.344..  Test Loss 0.342..  Test Accuracy 0.000
# Epoch: 55/100..  Training Loss 0.343..  Test Loss 0.342..  Test Accuracy 1.000
# Epoch: 56/100..  Training Loss 0.342..  Test Loss 0.342..  Test Accuracy 0.000
# Epoch: 57/100..  Training Loss 0.343..  Test Loss 0.341..  Test Accuracy 0.000
# Epoch: 58/100..  Training Loss 0.340..  Test Loss 0.341..  Test Accuracy 1.000
# Epoch: 59/100..  Training Loss 0.344..  Test Loss 0.341..  Test Accuracy 0.000
# Epoch: 60/100..  Training Loss 0.340..  Test Loss 0.341..  Test Accuracy 1.000
# Epoch: 61/100..  Training Loss 0.342..  Test Loss 0.341..  Test Accuracy 1.000
# Epoch: 62/100..  Training Loss 0.339..  Test Loss 0.340..  Test Accuracy 1.000
# Epoch: 63/100..  Training Loss 0.342..  Test Loss 0.340..  Test Accuracy 1.000
# Epoch: 64/100..  Training Loss 0.343..  Test Loss 0.340..  Test Accuracy 0.000
# Epoch: 65/100..  Training Loss 0.340..  Test Loss 0.340..  Test Accuracy 1.000
# Epoch: 66/100..  Training Loss 0.342..  Test Loss 0.340..  Test Accuracy 1.000
# Epoch: 67/100..  Training Loss 0.339..  Test Loss 0.339..  Test Accuracy 1.000
# Epoch: 68/100..  Training Loss 0.343..  Test Loss 0.339..  Test Accuracy 1.000
# Epoch: 69/100..  Training Loss 0.343..  Test Loss 0.339..  Test Accuracy 0.000
# Epoch: 70/100..  Training Loss 0.342..  Test Loss 0.339..  Test Accuracy 0.000
# Epoch: 71/100..  Training Loss 0.342..  Test Loss 0.338..  Test Accuracy 0.000
# Epoch: 72/100..  Training Loss 0.343..  Test Loss 0.338..  Test Accuracy 1.000
# Epoch: 73/100..  Training Loss 0.339..  Test Loss 0.338..  Test Accuracy 1.000
# Epoch: 74/100..  Training Loss 0.341..  Test Loss 0.338..  Test Accuracy 1.000
# Epoch: 75/100..  Training Loss 0.337..  Test Loss 0.337..  Test Accuracy 1.000
# Epoch: 76/100..  Training Loss 0.341..  Test Loss 0.337..  Test Accuracy 0.000
# Epoch: 77/100..  Training Loss 0.342..  Test Loss 0.337..  Test Accuracy 0.000
# Epoch: 78/100..  Training Loss 0.341..  Test Loss 0.337..  Test Accuracy 0.000
# Epoch: 79/100..  Training Loss 0.337..  Test Loss 0.336..  Test Accuracy 1.000
# Epoch: 80/100..  Training Loss 0.340..  Test Loss 0.336..  Test Accuracy 0.000
# Epoch: 81/100..  Training Loss 0.344..  Test Loss 0.336..  Test Accuracy 1.000
# Epoch: 82/100..  Training Loss 0.340..  Test Loss 0.335..  Test Accuracy 1.000
# Epoch: 83/100..  Training Loss 0.343..  Test Loss 0.335..  Test Accuracy 1.000
# Epoch: 84/100..  Training Loss 0.337..  Test Loss 0.335..  Test Accuracy 1.000
# Epoch: 85/100..  Training Loss 0.336..  Test Loss 0.335..  Test Accuracy 1.000
# Epoch: 86/100..  Training Loss 0.343..  Test Loss 0.334..  Test Accuracy 1.000
# Epoch: 87/100..  Training Loss 0.336..  Test Loss 0.334..  Test Accuracy 0.000
# Epoch: 88/100..  Training Loss 0.332..  Test Loss 0.334..  Test Accuracy 1.000
# Epoch: 89/100..  Training Loss 0.336..  Test Loss 0.333..  Test Accuracy 0.000
# Epoch: 90/100..  Training Loss 0.339..  Test Loss 0.333..  Test Accuracy 1.000
# Epoch: 91/100..  Training Loss 0.337..  Test Loss 0.333..  Test Accuracy 1.000
# Epoch: 92/100..  Training Loss 0.337..  Test Loss 0.332..  Test Accuracy 1.000
# Epoch: 93/100..  Training Loss 0.339..  Test Loss 0.332..  Test Accuracy 1.000
# Epoch: 94/100..  Training Loss 0.341..  Test Loss 0.332..  Test Accuracy 1.000
# Epoch: 95/100..  Training Loss 0.334..  Test Loss 0.331..  Test Accuracy 1.000
# Epoch: 96/100..  Training Loss 0.341..  Test Loss 0.331..  Test Accuracy 0.000
# Epoch: 97/100..  Training Loss 0.338..  Test Loss 0.331..  Test Accuracy 0.000
# Epoch: 98/100..  Training Loss 0.339..  Test Loss 0.331..  Test Accuracy 0.000
# Epoch: 99/100..  Training Loss 0.340..  Test Loss 0.331..  Test Accuracy 0.000
# Epoch: 100/100..  Training Loss 0.338..  Test Loss 0.330..  Test Accuracy 1.000
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\ritth\code\Strive\Strive-Exercises\Chapter 03\06. CNN\3. Exercise - Cat vs Dog.ipynb Cell 17' in <cell line: 82>()
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Strive-Exercises/Chapter%2003/06.%20CNN/3.%20Exercise%20-%20Cat%20vs%20Dog.ipynb#ch0000015?line=79'>80</a> plt.plot(x_epochs, train_losses, marker='o', label='train')
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Strive-Exercises/Chapter%2003/06.%20CNN/3.%20Exercise%20-%20Cat%20vs%20Dog.ipynb#ch0000015?line=80'>81</a> plt.plot(x_epochs, test_losses, marker='o', label='test')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Strive-Exercises/Chapter%2003/06.%20CNN/3.%20Exercise%20-%20Cat%20vs%20Dog.ipynb#ch0000015?line=81'>82</a> plt.plot(x_epochs, test_accuracies, marker='o', label='test')
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Strive-Exercises/Chapter%2003/06.%20CNN/3.%20Exercise%20-%20Cat%20vs%20Dog.ipynb#ch0000015?line=82'>83</a> plt.xlabel('Epoch')
#      <a href='vscode-notebook-cell:/c%3A/Users/ritth/code/Strive/Strive-Exercises/Chapter%2003/06.%20CNN/3.%20Exercise%20-%20Cat%20vs%20Dog.ipynb#ch0000015?line=83'>84</a> plt.ylabel('Loss')
#
# File c:\Users\ritth\software\anaconda\envs\deep\lib\site-packages\matplotlib\pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/pyplot.py?line=2766'>2767</a> @_copy_docstring_and_deprecators(Axes.plot)
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/pyplot.py?line=2767'>2768</a> def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/pyplot.py?line=2768'>2769</a>     return gca().plot(
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/pyplot.py?line=2769'>2770</a>         *args, scalex=scalex, scaley=scaley,
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/pyplot.py?line=2770'>2771</a>         **({"data": data} if data is not None else {}), **kwargs)
#
# File c:\Users\ritth\software\anaconda\envs\deep\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1389'>1390</a> """
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1390'>1391</a> Plot y versus x as lines and/or markers.
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1391'>1392</a>
#    (...)
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1628'>1629</a> (``'green'``) or hex strings (``'#008000'``).
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1629'>1630</a> """
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1630'>1631</a> kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1631'>1632</a> lines = [*self._get_lines(*args, data=data, **kwargs)]
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1632'>1633</a> for line in lines:
#    <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_axes.py?line=1633'>1634</a>     self.add_line(line)
#
# File c:\Users\ritth\software\anaconda\envs\deep\lib\site-packages\matplotlib\axes\_base.py:312, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=309'>310</a>     this += args[0],
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=310'>311</a>     args = args[1:]
# --> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=311'>312</a> yield from self._plot_args(this, kwargs)
#
# File c:\Users\ritth\software\anaconda\envs\deep\lib\site-packages\matplotlib\axes\_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=494'>495</a>     self.axes.yaxis.update_units(y)
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=496'>497</a> if x.shape[0] != y.shape[0]:
# --> <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=497'>498</a>     raise ValueError(f"x and y must have same first dimension, but "
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=498'>499</a>                      f"have shapes {x.shape} and {y.shape}")
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=499'>500</a> if x.ndim > 2 or y.ndim > 2:
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=500'>501</a>     raise ValueError(f"x and y can be no greater than 2D, but have "
#     <a href='file:///c%3A/Users/ritth/software/anaconda/envs/deep/lib/site-packages/matplotlib/axes/_base.py?line=501'>502</a>                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (1,)
